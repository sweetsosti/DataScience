# %%
import numpy as np

while True:
    user_input = input("Enter 22 numbers separated by commas (or type 'exit' to stop): ")
    
    if user_input.lower() == 'exit':
        break  # Exit the loop if the user types 'exit'

    try:
        values = list(map(int, user_input.split(',')))  # Convert input to a list of integers
        
        if len(values) != 22:
            print("❌ Error: You must enter exactly 22 numbers!")
            continue  # Ask again
        
        transformed_data = pca1.transform([values])  # Apply PCA
        prediction = model1.predict(transformed_data)  # Predict
        
        result = "Poisonous" if prediction[0] == 1 else "Edible"
        print(f"✅ Prediction: {result}\n")

    except ValueError:
        print("❌ Error: Please enter only numbers separated by commas!")
# Out:
# Enter 22 numbers separated by commas (or type 'exit' to stop):  [5,1,4,1,6,1,0,1,2,0,3,1,2,7,7,0,2,1,4,2,3,5]
# ❌ Error: Please enter only numbers separated by commas!
# Enter 22 numbers separated by commas (or type 'exit' to stop):  5,1,4,1,6,1,0,1,2,0,3,1,2,7,7,0,2,1,4,2,3,5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13     print("❌ Error: You must enter exactly 22 numbers!")
#      14     continue  # Ask again
# ---> 16 transformed_data = pca1.transform([values])  # Apply PCA
#      17 prediction = model1.predict(transformed_data)  # Predict
#      19 result = "Poisonous" if prediction[0] == 1 else "Edible"
#
# NameError: name 'pca1' is not defined
